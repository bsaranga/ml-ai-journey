# %% [markdown]
# # Data Exploration with Pandas

# %%
import pandas as pd

mlb_housing_path = './datasets/melb_data.csv'
mlb_housing_data = pd.read_csv(mlb_housing_path)
mlb_housing_data.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford    40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford         55a Park St      4    h  1600000.0     VB  Nelson
# 5  Abbotsford      129 Charles St      2    h   941000.0      S  Jellis
# 6  Abbotsford        124 Yarra St      3    h  1876000.0      S  Nelson
# 7  Abbotsford       98 Charles St      2    h  1636000.0      S  Nelson
# 8  Abbotsford  6/241 Nicholson St      1    u   300000.0      S  Biggin
# 9  Abbotsford       10 Valiant St      2    h  1097000.0      S  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# ...

# %%
mlb_housing_data.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

mlb_housing_data.dropna()

dependent_variable = 'Price'
independent_variable = 'Landsize'

lower_bound = 1
upper_bound = 2000

# Filter out rows where 'y' is within the bounds
df_no_outliers = mlb_housing_data[(mlb_housing_data[independent_variable] > lower_bound) & (mlb_housing_data[independent_variable] <= upper_bound)]

# Select the columns for plotting
x_values = df_no_outliers[independent_variable]
y_values = df_no_outliers[dependent_variable]

plt.figure(figsize=(20, 10))  # Set the figure size (optional)
plt.scatter(x_values, y_values, marker='.', linestyle='-', color='b', label='Data Points')  # Plotting with markers
plt.xlabel(independent_variable)  # Set the x-axis label
plt.ylabel(dependent_variable)  # Set the y-axis label
plt.title('Housing Price vs Land Size')  # Set the plot title
plt.legend()  # Show legend (if applicable)
plt.show()  # Display the plot
